# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('tags.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
len(ratings['userId'].unique())
# Out:
# 138493

# %%
# taking those users who have rated the movies more than 100 times 
x = pd.DataFrame(ratings['userId'].value_counts())
x = x.reset_index()
x.rename(columns = {'index':'User ID','userId':'No. of Ratings'}, inplace = True)
x = x.loc[x['No. of Ratings'] > 100]
x
# Out:
#        User ID  No. of Ratings
# 0       118205            9254
# 1         8405            7515
# 2        82418            5646
# 3       121535            5520
# 4       125794            5491
# ...        ...             ...
# 51864      565             101
# 51865    84809             101
# 51866    63209             101
# 51867    29682             101
# 51868    21042             101
#
# [51869 rows x 2 columns]

# %%
# merging ratings and x
ratings_refined = ratings.merge(x, left_on='userId', right_on='User ID')
ratings_refined
# Out:
#           userId  movieId  rating   timestamp  User ID  No. of Ratings
# 0              1        2     3.5  1112486027        1             175
# 1              1       29     3.5  1112484676        1             175
# 2              1       32     3.5  1112484819        1             175
# 3              1       47     3.5  1112484727        1             175
# 4              1       50     3.5  1112484580        1             175
# ...          ...      ...     ...         ...      ...             ...
# 15970199  138493    68954     4.5  1258126920   138493             373
# 15970200  138493    69526     4.5  1259865108   138493             373
# 15970201  138493    69644     3.0  1260209457   138493             373
# 15970202  138493    70286     5.0  1258126944   138493             373
# 15970203  138493    71619     2.5  1255811136   138493             373
#
# [15970204 rows x 6 columns]

# %%
# dropping the columns which are not required
ratings_refined = ratings_refined.drop(columns = ['timestamp', 'User ID', 'No. of Ratings'])

# %%
# merging ratings_refined and movies
movie_details=movies.merge(ratings_refined,on='movieId')
movie_details
# Out:
#           movieId                          title  \
# 0               1               Toy Story (1995)
# 1               1               Toy Story (1995)
# 2               1               Toy Story (1995)
# 3               1               Toy Story (1995)
# 4               1               Toy Story (1995)
# ...           ...                            ...
# 15970199   131254   Kein Bund für's Leben (2007)
# 15970200   131256  Feuer, Eis & Dosenbier (2002)
# 15970201   131258             The Pirates (2014)
# 15970202   131260            Rentun Ruusu (2001)
# 15970203   131262               Innocence (2014)
#
#                                                genres  userId  rating
# 0         Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy      11     4.5
# 2         Adventure|Animation|Children|Comedy|Fantasy      14     4.5
# 3         Adventure|Animation|Children|Comedy|Fantasy      22     3.0
# 4         Adventure|Animation|Children|Comedy|Fantasy      23     4.0
# ...                                               ...     ...     ...
# 15970199                                       Comedy   79570     4.0
# 15970200                                       Comedy   79570     4.0
# 15970201                                    Adventure   28906     2.5
# 15970202                           (no genres listed)   65409     3.0
# 15970203                     Adventure|Fantasy|Horror  133047     4.0
#
# [15970204 rows x 5 columns]

# %%
# taking those movies who have ratings more than 25 times 
x=pd.DataFrame(movie_details['movieId'].value_counts())
x=x.reset_index()
x.rename(columns = {'index':'Movie ID','movieId':'No. of Ratings'}, inplace = True)
x = x.loc[x['No. of Ratings'] > 25]
x
# Out:
#        Movie ID  No. of Ratings
# 0           356           37657
# 1           296           37016
# 2           593           35723
# 3           480           35204
# 4          2571           34515
# ...         ...             ...
# 12232     96510              26
# 12233     33847              26
# 12234     62925              26
# 12235     60992              26
# 12236      3866              26
#
# [12237 rows x 2 columns]

# %%
# merging x and movie_details
movie_details_refined=movie_details.merge(x, left_on='movieId', right_on='Movie ID')
movie_details_refined=movie_details_refined.drop(columns=['Movie ID', 'No. of Ratings'])
movie_details_refined
# Out:
#           movieId                                        title  \
# 0               1                             Toy Story (1995)
# 1               1                             Toy Story (1995)
# 2               1                             Toy Story (1995)
# 3               1                             Toy Story (1995)
# 4               1                             Toy Story (1995)
# ...           ...                                          ...
# 15887081   127098  Louis C.K.: Live at The Comedy Store (2015)
# 15887082   127098  Louis C.K.: Live at The Comedy Store (2015)
# 15887083   127098  Louis C.K.: Live at The Comedy Store (2015)
# 15887084   127098  Louis C.K.: Live at The Comedy Store (2015)
# 15887085   127098  Louis C.K.: Live at The Comedy Store (2015)
#
#                                                genres  userId  rating
# 0         Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy      11     4.5
# 2         Adventure|Animation|Children|Comedy|Fantasy      14     4.5
# 3         Adventure|Animation|Children|Comedy|Fantasy      22     3.0
# 4         Adventure|Animation|Children|Comedy|Fantasy      23     4.0
# ...                                               ...     ...     ...
# 15887081                                       Comedy  115134     5.0
# 15887082                                       Comedy  117144     3.5
# 15887083                                       Comedy  121631     3.5
# 15887084                                       Comedy  134567     3.5
# 15887085                                       Comedy  136684     4.5
#
# [15887086 rows x 5 columns]

# %%
# dropping all the duplicate values
movie_details_refined.drop_duplicates(subset = ['title','userId'],inplace=True)
movie_details_refined.shape
# Out:
# (15886788, 5)

# %%
# creating the pivot table
movie_pivot = movie_details_refined.pivot_table(columns='userId',index='title',values='rating')
movie_pivot
# Out:
# userId                                         1       3       7       11      \
# title
# "Great Performances" Cats (1998)                  NaN     NaN     NaN     NaN
# $9.99 (2008)                                      NaN     NaN     NaN     NaN
# '71 (2014)                                        NaN     NaN     NaN     NaN
# 'Hellboy': The Seeds of Creation (2004)           NaN     NaN     NaN     NaN
# 'Round Midnight (1986)                            NaN     NaN     NaN     NaN
# ...                                               ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies (2006)     NaN     NaN     NaN     NaN
# xXx (2002)                                        NaN     NaN     NaN     NaN
# xXx: State of the Union (2005)                    NaN     NaN     NaN     NaN
# ¡Three Amigos! (1986)                             NaN     NaN     2.0     NaN
# À nous la liberté (Freedom for Us) (1931)         NaN     NaN     NaN     NaN
#
# userId                                         14      18      21      22      \
# title
# "Great Performances" Cats (1998)                  NaN     NaN     NaN     NaN
# $9.99 (2008)                                      NaN     NaN     NaN     NaN
# '71 (2014)                                        NaN     NaN     NaN     NaN
# 'Hellboy': The Seeds of Creation (2004)           NaN     NaN     NaN     NaN
# 'Round Midnight (1986)                            NaN     NaN     NaN     NaN
# ...                                               ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies (2006)     NaN     NaN     NaN     NaN
# xXx (2002)                                        NaN     NaN     NaN     NaN
# xXx: State of the Union (2005)                    NaN     NaN     NaN     NaN
# ¡Three Amigos! (1986)                             NaN     NaN     NaN     NaN
# À nous la liberté (Freedom for Us) (1931)         NaN     NaN     NaN     NaN
#
# userId                                         23      24      ...  138471  \
# title                                                          ...
# "Great Performances" Cats (1998)                  NaN     NaN  ...     NaN
# $9.99 (2008)                                      NaN     NaN  ...     NaN
# '71 (2014)                                        NaN     NaN  ...     NaN
# 'Hellboy': The Seeds of Creation (2004)           NaN     NaN  ...     NaN
# 'Round Midnight (1986)                            NaN     NaN  ...     NaN
# ...                                               ...     ...  ...     ...
# loudQUIETloud: A Film About the Pixies (2006)     NaN     NaN  ...     NaN
# xXx (2002)                                        NaN     NaN  ...     NaN
# xXx: State of the Union (2005)                    NaN     NaN  ...     NaN
# ¡Three Amigos! (1986)                             NaN     NaN  ...     NaN
# À nous la liberté (Freedom for Us) (1931)         NaN     NaN  ...     NaN
#
# userId                                         138472  138474  138475  138477  \
# title
# "Great Performances" Cats (1998)                  NaN     NaN     NaN     NaN
# $9.99 (2008)                                      NaN     NaN     NaN     NaN
# '71 (2014)                                        NaN     NaN     NaN     NaN
# 'Hellboy': The Seeds of Creation (2004)           NaN     NaN     NaN     NaN
# 'Round Midnight (1986)                            NaN     NaN     NaN     NaN
# ...                                               ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies (2006)     NaN     NaN     NaN     NaN
# xXx (2002)                                        NaN     NaN     NaN     1.0
# xXx: State of the Union (2005)                    NaN     NaN     NaN     NaN
# ¡Three Amigos! (1986)                             NaN     NaN     NaN     NaN
# À nous la liberté (Freedom for Us) (1931)         NaN     NaN     NaN     NaN
#
# userId                                         138483  138484  138486  138490  \
# title
# "Great Performances" Cats (1998)                  NaN     NaN     NaN     NaN
# $9.99 (2008)                                      NaN     NaN     NaN     NaN
# '71 (2014)                                        NaN     NaN     NaN     NaN
# 'Hellboy': The Seeds of Creation (2004)           NaN     NaN     NaN     NaN
# 'Round Midnight (1986)                            NaN     NaN     NaN     NaN
# ...                                               ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies (2006)     NaN     NaN     NaN     NaN
# xXx (2002)                                        NaN     NaN     NaN     NaN
# xXx: State of the Union (2005)                    NaN     NaN     NaN     NaN
# ¡Three Amigos! (1986)                             NaN     NaN     NaN     NaN
# À nous la liberté (Freedom for Us) (1931)         NaN     NaN     NaN     NaN
#
# userId                                         138493
# title
# "Great Performances" Cats (1998)                  NaN
# $9.99 (2008)                                      NaN
# '71 (2014)                                        NaN
# 'Hellboy': The Seeds of Creation (2004)           NaN
# 'Round Midnight (1986)                            NaN
# ...                                               ...
# loudQUIETloud: A Film About the Pixies (2006)     NaN
# xXx (2002)                                        NaN
# xXx: State of the Union (2005)                    NaN
# ¡Three Amigos! (1986)                             NaN
# À nous la liberté (Freedom for Us) (1931)         NaN
#
# [12234 rows x 51869 columns]

# %%
movie_pivot.shape
# Out:
# (12234, 51869)

# %%
movie_pivot.fillna(0,inplace=True)
movie_pivot
# Out:
# userId                                         1       3       7       11      \
# title
# "Great Performances" Cats (1998)                  0.0     0.0     0.0     0.0
# $9.99 (2008)                                      0.0     0.0     0.0     0.0
# '71 (2014)                                        0.0     0.0     0.0     0.0
# 'Hellboy': The Seeds of Creation (2004)           0.0     0.0     0.0     0.0
# 'Round Midnight (1986)                            0.0     0.0     0.0     0.0
# ...                                               ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies (2006)     0.0     0.0     0.0     0.0
# xXx (2002)                                        0.0     0.0     0.0     0.0
# xXx: State of the Union (2005)                    0.0     0.0     0.0     0.0
# ¡Three Amigos! (1986)                             0.0     0.0     2.0     0.0
# À nous la liberté (Freedom for Us) (1931)         0.0     0.0     0.0     0.0
#
# userId                                         14      18      21      22      \
# title
# "Great Performances" Cats (1998)                  0.0     0.0     0.0     0.0
# $9.99 (2008)                                      0.0     0.0     0.0     0.0
# '71 (2014)                                        0.0     0.0     0.0     0.0
# 'Hellboy': The Seeds of Creation (2004)           0.0     0.0     0.0     0.0
# 'Round Midnight (1986)                            0.0     0.0     0.0     0.0
# ...                                               ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies (2006)     0.0     0.0     0.0     0.0
# xXx (2002)                                        0.0     0.0     0.0     0.0
# xXx: State of the Union (2005)                    0.0     0.0     0.0     0.0
# ¡Three Amigos! (1986)                             0.0     0.0     0.0     0.0
# À nous la liberté (Freedom for Us) (1931)         0.0     0.0     0.0     0.0
#
# userId                                         23      24      ...  138471  \
# title                                                          ...
# "Great Performances" Cats (1998)                  0.0     0.0  ...     0.0
# $9.99 (2008)                                      0.0     0.0  ...     0.0
# '71 (2014)                                        0.0     0.0  ...     0.0
# 'Hellboy': The Seeds of Creation (2004)           0.0     0.0  ...     0.0
# 'Round Midnight (1986)                            0.0     0.0  ...     0.0
# ...                                               ...     ...  ...     ...
# loudQUIETloud: A Film About the Pixies (2006)     0.0     0.0  ...     0.0
# xXx (2002)                                        0.0     0.0  ...     0.0
# xXx: State of the Union (2005)                    0.0     0.0  ...     0.0
# ¡Three Amigos! (1986)                             0.0     0.0  ...     0.0
# À nous la liberté (Freedom for Us) (1931)         0.0     0.0  ...     0.0
#
# userId                                         138472  138474  138475  138477  \
# title
# "Great Performances" Cats (1998)                  0.0     0.0     0.0     0.0
# $9.99 (2008)                                      0.0     0.0     0.0     0.0
# '71 (2014)                                        0.0     0.0     0.0     0.0
# 'Hellboy': The Seeds of Creation (2004)           0.0     0.0     0.0     0.0
# 'Round Midnight (1986)                            0.0     0.0     0.0     0.0
# ...                                               ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies (2006)     0.0     0.0     0.0     0.0
# xXx (2002)                                        0.0     0.0     0.0     1.0
# xXx: State of the Union (2005)                    0.0     0.0     0.0     0.0
# ¡Three Amigos! (1986)                             0.0     0.0     0.0     0.0
# À nous la liberté (Freedom for Us) (1931)         0.0     0.0     0.0     0.0
#
# userId                                         138483  138484  138486  138490  \
# title
# "Great Performances" Cats (1998)                  0.0     0.0     0.0     0.0
# $9.99 (2008)                                      0.0     0.0     0.0     0.0
# '71 (2014)                                        0.0     0.0     0.0     0.0
# 'Hellboy': The Seeds of Creation (2004)           0.0     0.0     0.0     0.0
# 'Round Midnight (1986)                            0.0     0.0     0.0     0.0
# ...                                               ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies (2006)     0.0     0.0     0.0     0.0
# xXx (2002)                                        0.0     0.0     0.0     0.0
# xXx: State of the Union (2005)                    0.0     0.0     0.0     0.0
# ¡Three Amigos! (1986)                             0.0     0.0     0.0     0.0
# À nous la liberté (Freedom for Us) (1931)         0.0     0.0     0.0     0.0
#
# userId                                         138493
# title
# "Great Performances" Cats (1998)                  0.0
# $9.99 (2008)                                      0.0
# '71 (2014)                                        0.0
# 'Hellboy': The Seeds of Creation (2004)           0.0
# 'Round Midnight (1986)                            0.0
# ...                                               ...
# loudQUIETloud: A Film About the Pixies (2006)     0.0
# xXx (2002)                                        0.0
# xXx: State of the Union (2005)                    0.0
# ¡Three Amigos! (1986)                             0.0
# À nous la liberté (Freedom for Us) (1931)         0.0
#
# [12234 rows x 51869 columns]

# %%
# converting movie_pivot into csr matrix (memory efficient) as It is wasteful to store the zero elements 
# in the matrix since they do not affect the results of our computation
from scipy.sparse import csr_matrix

movie_pivot_sparse = csr_matrix(movie_pivot)

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(n_neighbors = 7,algorithm='brute', metric='cosine')

# Fit the nearest neighbors estimator from the training dataset
model.fit(movie_pivot_sparse)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=7)

# %%
def movie_recommend(moviename):
    j = 0
    for i in movie_pivot.index:
        if moviename == i:
            break
        j+=1
    index = j
    # Finding the K-neighbors of a point. # reshape(1,-1) - > as 2D array required
    l = []
    distances,suggestions = model.kneighbors(movie_pivot.iloc[index,:].values.reshape(1,-1))
    for i in range(len(suggestions)):
        return (movie_pivot.index[suggestions[i]])

# %%
recommendation = movie_recommend("Spider (2002)")

# %%
for i in recommendation:
    print(i)
# Out:
# Spider (2002)
# Videodrome (1983)
# Naked Lunch (1991)
# Man Who Wasn't There, The (2001)
# Mulholland Drive (2001)
# Elephant (2003)
# History of Violence, A (2005)
